# %% [markdown]
# Q1. What is a parameter?
# A1. parameter is a variable in a model that the algorithm adjusts during training to optimize performance.
#
#
#
#
# Q2. What is correlation?
# A2. Correlation is a statistical measure that expresses the extent to which two variables are linearly related.
#
# Q3. What does negative correlation mean?
# A3. Negative correlation means that as one variable increases, the other decreases.
#
#
# Q4. Define Machine Learning.What are the main components in Machine Learning?
# A4. Machine Learning is a field of study that enables computers to learn from data and make predictions or decisions without being explicitly programmed. ​The main components are data, model, algorithm, and evaluation metrics.
#
#
# Q5. How does loss value help in determining whether the model is good or not?
# A5. Loss value quantifies the error between predicted and actual values. A lower loss value indicates a better model.
#
#
# Q6. What are continuous and categorical variables ?
# A6. CONTINUOUS VARIABLE
# - These are numerical variables that can take any value within range. The values are measurable and typically have an infinite number of possible values between any two points
# Example- height,weight,time etc
#
# CATEGORIAL VARIABLES
# - These rpresents groups or categories.  they have a finite set of values,often qualitative in nature
#
#
#
#
#
# Q7. How do we handle categorical variables in Machine Learning?What are the common techniques?
# A7. Handling categorial variables in machine learning is crucial because most algorithms require numerical inputs.Common techniques include one-hot encoding, label encoding, and binary encoding.
#
#
# Q8. What do you mean by training and testing a dataset?
# A8. Training a dataset involves using data to train the model, while testing evaluates the model's performance on unseen data.
#
#
# Q9. What is sklearn.preprocessing?
# A9. sklearn.preprocessing is a module in Python's scikit-learn library used for data preprocessing tasks like scaling, encoding, and normalization.
#
#
# Q10. What is a Test set?
# A10. A test set is a portion of the dataset used to evaluate the model's performance after training.
#
#
# Q11. How do we split data for model fitting (training and testing) in Python?
# A11. Data can be split using train_test_split from scikit-learn.
#
#
# Q12. How do you approach a Machine Learning problem?
# A12. The approach includes understanding the problem, collecting and preprocessing data, performing exploratory data analysis (EDA), selecting a model, training, testing, and evaluating the model.
#
#
#
# Q13. Why do we have to perform EDA before fitting a model to the data?
# A13. EDA helps understand the data, identify patterns, detect anomalies, and prepare the data for modeling.
#
#
#
# Q14. What is correlation?
# A14. Correlation measures the relationship between two variables.
#
#
#
# Q15. What does negative correlation mean?
# A15. Negative correlation indicates an inverse relationship between two variables.
#
#
# Q16. How can you find correlation between variables in Python?
# A16. Correlation can be calculated using pandas.DataFrame.corr() or numpy.corrcoef().
#
#
#
# Q17. What is causation?Explain difference between correlation and causation with an example.
# A17. Causation implies that one variable directly affects another, while correlation indicates a relationship without implying cause.Example: Ice cream sales and drowning incidents may correlate, but eating ice cream does not cause drowning.
#
#
#
# Q18. What is an Optimizer? What are different types of optimizers? Explain each with an example.
# A18. An optimizer in machine learning is an algorithm used to adjust the weights of a model in order to minimize the loss function
# types of optimizers:
# 1. GRADIENT DESCENT (GD)
# - uses the full dataset to compute gradient and update parameters
# - accurate updates
# - slow for large dataset
# - Example: pseudo-code
#         for epoch in range(epochs):
#             gradiants = compute_gradient(X_full, y_full)
#             weights = weights - learning_rate * gradients
#
# 2. STOCHASTIC GRADIENT DESCENT (SGD)
# - Uses one random sample per update
# - Faster than GD, but more noisy updates.
# - Great for large datasets
# - Examples:
#             for epoch in range(epochs):
#                 for i in range(n_samples):
#                     xi, yi = X[i], y[i]
#                     gradients = compute_gradients(xi, yi)
#                     weights = weights - learning_rate * gradients
#
# 3. MINI_BATCH GRADIENT DESCENT
# - Compromise between GD anf SGD
# - Uses small batches for update
# - Widely used in practice
#
# 4. MOMENTUM
# - Add a velocity term to remember the direction of the past gradients
# - Helps accelerate and reduce oscillations
# - Example:
#            optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.9)
#
# 5. RMSprop
# - Divides learning rate by a moving average of a squared gradients
# - Adapts learning rate for each parameter
# - Good for non-stationary objectives
# - Examples:
#            optimizer = torch.optim.RMSprop(model.parameters(), lr=0.001)
#
#
#
# Q19. What is sklearn.linear_model?
# A19. sklearn.linear_model is a module in scikit-learn for implementing linear models like Linear Regression and Logistic Regression.
#
#
#
# Q20. What does model.fit() do? What arguments must be given?
# A20. model.fit() trains the model using input data and labels. Arguments include training data (X) and target labels (y).
#
#
#
# Q21. What does model.predict() do? What arguments must be given?
# A21. model.predict() generates predictions based on input data.Arguments include test data (X).
#
#
#
# Q22. What are continuous and categorical variables?
# A22. Continuous variables are numerical and can take any value. Categorical variables represent discrete categories.
#
#
#
#
# Q23. What is feature scaling? How does it help in Machine Learning?
# A23. Feature scaling standardizes the range of features, improving model performance and convergence.
#
#
#
# Q24. How do we perform scaling in Python?
# A24. Scaling can be performed using StandardScaler or MinMaxScaler from scikit-learn.
#
#
#
# Q25. What is sklearn.preprocessing?
# A25. sklearn.preprocessing is a module for preprocessing tasks like scaling and encoding.
#
#
#
# Q26. How do we split data for model fitting (training and testing) in Python?
# A26. Data can be split using train_test_split from scikit-learn.
#
#
#
# Q27. Explain data encoding?
# A27. Data encoding transforms categorical variables into numerical formats, such as one-hot encoding or label encoding.
